# %% [markdown]
# **1.3 Some Hidden Messages are More Surprising than Others:**
# Code Challenge: Solve the Pattern Matching Problem.
#
#
# Input: Two strings, Pattern and Genome
#
# Output: A collection of space-separated integers specifying all starting positions where Pattern appears as a substring of Genome.
#
# ---
#
# ###**Sample Input:**
# ```
# ATAT
# GATATATGCATATACTT
# ```
# ###**Sample Output:**
# ```
# 1 3 9
# ```

# %%
INPUT_GENOME = "..."
INPUT_PATTERN = "CACGGCCCA"

# %%
def find_initial_position_pattern(genome, pattern):
  for index in range(0, len(genome)):
      current_str = genome[index: index + len(pattern)]
      if current_str == pattern:
        print(index, end=" ")

# %%
find_initial_position_pattern(INPUT_GENOME, INPUT_PATTERN)
# Out:
# 45 54 61 98 105 112 119 126 158 183 190 252 305 351 433 440 447 454 485 492 507 550 579 586 593 686 703 750 757 802 809 883 890 905 929 1071 1146 1184 1191 1256 1271 1349 1356 1455 1462 1469 1495 1597 1626 1633 1640 1649 1656 1675 1739 1761 1863 1898 1920 1948 1955 2010 2096 2131 2163 2170 2185 2229 2293 2323 2330 2386 2404 2419 2445 2497 2504 2519 2571 2628 2691 2756 2790 2844 2851 3020 3040 3107 3114 3151 3158 3226 3244 3251 3290 3297 3321 3398 3539 3546 3555 3570 3645 3652 3722 3733 3752 3836 3931 3959 3974 4038 4053 4073 4111 4261 4268 4284 4291 4315 4338 4377 4401 4418 4451 4458 4475 4482 4513 4568 4598 4643 4714 4773 4790 4806 4816 4937 4960 4981 5023 5038 5053 5068 5088 5179 5186 5203 5262 5269 5297 5304 5311 5318 5325 5358 5383 5421 5464 5471 5563 5608 5625 5640 5659 5685 5709 5733 5835 5851 5858 5865 5913 6075 6116 6158 6165 6201 6208 6288 6356 6372 6407 6414 6424 6449 6456 6547 6554 6603 6655 6662 6789 6837 6884 6962 7002 7041 7081 7088 7107 7114 7241 7248 7264 7281 7384 74
# ...
