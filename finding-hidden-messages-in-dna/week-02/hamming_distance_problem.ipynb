# %%
def hamming_distance_problem(genome1, genome2):
  if len(genome1) == len(genome2):
      divergent = 0
      for (base_1, base_2) in zip(genome1, genome2):
          print(base_1, base_2)
          if base_1 != base_2:
              divergent = divergent + 1
      print(divergent)
  else:
      print("error!")

def genome_hamming_problem

genome1 = "..."
genome2 = "..."
hamming_distance_problem(genome1, genome2)
# Out:
# A C
# G C
# T C
# A T
# C C
# A C
# G G
# G C
# A G
# G T
# A A
# T A
# T T
# C G
# C A
# T C
# G A
# T A
# G C
# G C
# A C
# A G
# T C
# T C
# C C
# T C
# C T
# T T
# T C
# T C
# C C
# G T
# C T
# C C
# A G
# G C
# C T
# G C
# A A
# T C
# G C
# G C
# A C
# T C
# T A
# T A
# G A
# A T
# G T
# T T
# G C
# T G
# A A
# C T
# G C
# C G
# T C
# A T
# G T
# T A
# C T
# G C
# A T
# T A
# T T
# G C
# T A
# C T
# G A
# T G
# T A
# T A
# T A
# C A
# A A
# T T
# G T
# T A
# C G
# A A
# C T
# A G
# G C
# T A
# C T
# G A
# T C
# T C
# A T
# T G
# T T
# A C
# T A
# G C
# T A
# A G
# G C
# T A
# A G
# T G
# T T
# G T
# A A
# G A
# A G
# G T
# A A
# A A
# T C
# T C
# A T
# T A
# A T
# A T
# C A
# A A
# A A
# C G
# A T
# C A
# A C
# C G
# T T
# T A
# G G
# T T
# T C
# T C
# C C
# C C
# G A
# G A
# G A
# C C
# C T
# C C
# T A
# C G
# A G
# T T
# T C
# C A
# C A
# C T
# G A
# C A
# C T
# G T
# A T
# T G
# C T
# G G
# T T
# A G
# G T
# T C
# G A
# A T
# T A
# C T
# G C
# G C
# T C
# C A
# C A
# G G
# ...
